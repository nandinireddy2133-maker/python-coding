# %%
a = "Edukron Data Science and Data Engineering Batch 2026"

# %%
Edukron
Data
Science
and
Data Engineering
Engineering
Batch
2026
Science and Data
Data Science and Data Engineering Batch

# %%
a[0:7]
# Out:
# 'Edukron'

# %%
a[8:12]
# Out:
# 'Data'

# %%
a[13:20]
# Out:
# 'Science'

# %%
a[21:24]
# Out:
# 'and'

# %%
a[25:41]
# Out:
# 'Data Engineering'

# %%
a[30:41]
# Out:
# 'Engineering'

# %%
a[42:47]
# Out:
# 'Batch'

# %%
a[48:52]
# Out:
# '2026'

# %%
a[13:29]
# Out:
# 'Science and Data'

# %%
a[8:47]
# Out:
# 'Data Science and Data Engineering Batch'
