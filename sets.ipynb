# %% [markdown]
# Print the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print(customers)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# Find the number of elements in the customers set.

# %%
len(customers)
# Out:
# 5

# %% [markdown]
# Check whether "Rahul" exists in the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
if "Rahul" in customers:
    print("Rahul exists in the customers set.")
else:
    print("Rahul does not exist in the customers set.")
# Out:
# Rahul exists in the customers set.

# %% [markdown]
# Check whether "Meena" exists in the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
if "Meena" in customers:
    print("Meena exists in the customers set.")
else:
    print("Meena does not exist in the customers set.")
# Out:
# Meena does not exist in the customers set.

# %% [markdown]
# Iterate through all elements in the bank_branches set.

# %%
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}
for branch in bank_branches:
  print(branch)
# Out:
# MG Road
# Electronic City
# Indiranagar
# Whitefield

# %% [markdown]
# Add "Meena" to the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.add("meena")
print(customers)
# Out:
# {'meena', 'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# Add "Mysore" to the cities set.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.add("mysore")
print(cities)
# Out:
# {'Pune', 'Bangalore', 'mysore', 'Chennai', 'Hyderabad'}

# %% [markdown]
#  Update the `customers` set with `new_customers`.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.update(new_customers)
print(customers)
# Out:
# {'Amit', 'Rahul', 'Sneha', 'Kiran', 'Anita', 'Vikram', 'Priya', 'Divya'}

# %% [markdown]
# Update the cities set with new_cities.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}

new_cities = {"Mumbai", "Bangalore", "Delhi"}
cities.update(new_cities)
print(cities)
# Out:
# {'Pune', 'Delhi', 'Bangalore', 'Chennai', 'Hyderabad', 'Mumbai'}

# %% [markdown]
# Remove "Rahul" from the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.remove("Rahul")
print(customers)
# Out:
# {'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# Remove "Pune" from the cities set.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.remove("Pune")
print(cities)
# Out:
# {'Bangalore', 'Chennai', 'Hyderabad'}

# %% [markdown]
# Discard "Anita" from the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.discard("Anita")
print(customers)
# Out:
# {'Rahul', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# 13. Discard "Delhi" from the `cities` set.

# %%
cities = {"Mumbai", "Bangalore", "Delhi"}
cities.discard("Delhi")
print(cities)
# Out:
# {'Bangalore', 'Mumbai'}

# %% [markdown]
# Discard "Kolkata" from the cities set.

# %%
cities = {"Mumbai", "Bangalore", "Delhi","Kolkata"}
cities.discard("Kolkata")
print(cities)
# Out:
# {'Delhi', 'Bangalore', 'Mumbai'}

# %% [markdown]
# Remove a random element from the transaction_ids set using pop().

# %%
transaction_ids = {101, 102, 103, 104, 105}
removed_id=transaction_ids.pop()
print(removed_id)
# Out:
# 101

# %% [markdown]
# Remove another random element from the account_types set.

# %%
account_types = {"Savings", "Current", "Loan"}
removed_type=account_types.pop()
print(removed_type)
print(account_types)
# Out:
# Loan
# {'Current', 'Savings'}

# %% [markdown]
# Remove all elements from the balances set.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
balances.clear()
print(balances)
# Out:
# set()

# %% [markdown]
# Create a copy of the customers set.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers_copy=customers.copy()
print(customers_copy)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# Modify the copied set and verify that the original set remains unchanged.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers_copy=customers.copy()
customers_copy.add("meena")
customers_copy.remove("Rahul")
print(customers_copy)
print(customers)
# Out:
# {'meena', 'Anita', 'Vikram', 'Sneha', 'Kiran'}
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# Find the union of customers and new_customers.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
union_set=customers.union(new_customers)
print(union_set)
# Out:
# {'Amit', 'Rahul', 'Sneha', 'Kiran', 'Anita', 'Vikram', 'Priya', 'Divya'}

# %% [markdown]
# Find the common customers between customers and new_customers.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
common_customers=customers.intersection(new_customers)
print(common_customers)
# Out:
# {'Rahul'}

# %% [markdown]
# Find customers who have both Savings and Loan accounts

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
loan_savings_customers=loan_customers.intersection(savings_customers)
print(loan_savings_customers)
# Out:
# {'Rahul'}

# %% [markdown]
#  Find customers present only in `customers` but not in `new_customers`.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram","Amit"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers_only=customers.difference(new_customers)
print(customers_only)
# Out:
# {'Vikram', 'Sneha', 'Kiran', 'Anita'}

# %% [markdown]
# Find customers who have only Savings accounts.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
savings_only=savings_customers.difference(loan_customers)
print(savings_only)
# Out:
# {'Nikhil', 'Sneha', 'Priya'}

# %% [markdown]
# Find customers that are present in either `customers` or `new_customers` but not both.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram","Amit"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers_new_customers=customers.symmetric_difference(new_customers)
print(customers_new_customers)
# Out:
# {'Anita', 'Kiran', 'Vikram', 'Sneha', 'Priya', 'Divya'}

# %% [markdown]
# 26. Check whether `{"Rahul", "Kiran"}` is a subset of `loan_customers`.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
customers={"Rahul", "Kiran"}
subset_customers=customers.issubset(loan_customers)
print(subset_customers)
# Out:
# True

# %% [markdown]
#  Check whether `customers` is a superset of `{"Rahul", "Anita"}`.

# %%
superset={"Rahul", "Anita"}
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
superset_customers=customers.issuperset(superset)
print(superset_customers)
# Out:
# True

# %% [markdown]
# Check whether `loan_customers` and `new_cities` are disjoint.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
cities = {"Mumbai", "Bangalore", "Delhi","Kolkata"}
disjoint=loan_customers.isdisjoint(cities)
print(disjoint)
# Out:
# True

# %% [markdown]
# 29. Find the maximum balance in the `balances` set.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
max(balances)
# Out:
# 275000

# %% [markdown]
# Find the minimum balance in the balances set.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
min(balances)
# Out:
# 45000

# %% [markdown]
# Find the total of all balances.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(sum(balances))
# Out:
# 620000

# %% [markdown]
# Sort the balances set in ascending order.

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(sorted(balances))
print(sorted(balances, reverse=True))
# Out:
# [45000, 85000, 95000, 120000, 275000]
# [275000, 120000, 95000, 85000, 45000]

# %% [markdown]
# Convert the customers set into a list.

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
list(customers)
# Out:
# ['Vikram', 'Sneha', 'Kiran', 'Anita', 'Rahul']

# %% [markdown]
# Convert the `cities` set into a tuple.

# %%
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
tuple(cities)
# Out:
# ('Pune', 'Hyderabad', 'Chennai', 'Bangalore')

# %% [markdown]
# Remove duplicates from the list: ["Rahul", "Rahul", "Anita", "Sneha", "Sneha"] by converting it into a set.

# %%
customers=["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
customers=set(customers)
print(customers)
# Out:
# {'Sneha', 'Anita', 'Rahul'}

# %% [markdown]
# Create an empty set.

# %%
empty_set=set()
print(empty_set)
# Out:
# set()

# %% [markdown]
# Add five employee names to the empty set.

# %%
empty_set=set()
employees = ["Rahul","Anita","Kiran","Sneha","Vikram"]
empty_set.update(employees)
print(empty_set)
# Out:
# {'Sneha', 'Kiran', 'Vikram', 'Anita', 'Rahul'}

# %% [markdown]
# Find the length of the account_types set.

# %%
account_types = {"Savings", "Current", "Loan"}
len(account_types)
# Out:
# 3

# %% [markdown]
# Print every element of the loan_customers set using a loop.

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
for customer in loan_customers:
    print(customer)
# Out:
# Kiran
# Ramesh
# Asha
# Rahul

# %% [markdown]
# Clear the transaction_ids set and verify that it is empty.

# %%
transaction_ids = {101, 102, 103, 104, 105}
transaction_ids.clear()
transaction_ids
# Out:
# set()
